# %%
fruit = "banana"
letter = fruit[1]

print(letter)
# Out:
# a

# %%
# Lenght
fruit = "banana"
len(fruit)

# Traversal and the for loop 
index = 0
while index < len(fruit):
    letter = fruit[index]
    print(letter)
    index += 1


def exercise(n):
   reverse = n[::-1]
   
   for cha in reverse:
        print(cha)
        
        return reverse        
print(exercise("Hello"))


def exercise(n):
    reverse = n[::-1]  # Reverse the string
    
    for char in reverse:
        print(char)
    
    return reverse

print(exercise("Hello"))
# Out:
# b
# a
# n
# a
# n
# a
# o
# olleH
# o
# l
# l
# e
# H
# olleH

# %%
prefixes  = "JKLMNOPQ"
suffix = "ack"

for letter in prefixes:
    if letter in ["Q", "O"]:
        letter = letter + "u"
    print(letter + suffix)
# Out:
# Jack
# Kack
# Lack
# Mack
# Nack
# Ouack
# Pack
# Quack

# %%
# String Slice
s = "Peter, Paul, and Mary"
print(s[0:5])

print(s[7:11])
print(s[17:])

fruit = "banana"
fruit[:3]

fruit[3:]
fruit[:]
# Out:
# Peter
# Paul
# Mary
# 'banana'

# %%
# String Comparison
word = "banana"
if word == "banana":
    print(f"Yes we have bananas!")


greeting = "Hello"
new_greet = 'J' + greeting[1:]
print(new_greet)
# Out:
# Yes we have bananas!
# Jello

# %%
#Eureka Traversal 

def find(str, ch):
    index = 0
    while index  < len(str):
        if str[index] == ch:
            return index
        index += 1
    return -1

print(find("damilola", 'i'))


# As an exercise, modify the find function so that it has a third pa
# rameter, the index in the string where it should start looking

def find_start(str, ch, start):
    index = start 
    while index < len(str):
        if str[index] == ch:
            return index
        index += 1
    return -1
# Out:
# 3

# %%
fruit = 'banana'
count = 0
for ch in fruit:
    if ch == "n":
        count += 1
print(count)        


# As an exercise, encapsulate this code in a function named
# countLetters, and generalize it so that it accepts the string and
# the letter as arguments.

def countLetterss(str, ch):
    count = 0
    for char in str:
        if char == ch:
            count += 1
    return count
print(countLetterss('hippopotamus', 'p'))            


# As a second exercise, rewrite this function so that instead of traversing
# the string, it uses the three-parameter version of find from the previous

def countL(s, ch, start):
    count = 0
    index = find_start(s, ch, start)

    while index != -1:
        count += 1
        index = find_start(s, ch, index + 1)

    return count
print(countL("happy", "p", 2))
# Out:
# 2
# 3
# 2

# %%
import string as s

fruit = 'banana'
index = fruit.find( 'a', 4)
print(index)
# Out:
# 5
